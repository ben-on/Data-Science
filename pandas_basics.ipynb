# %%
import pandas as pd

# %% [markdown]
# <h5><b>1. Create</b></h5>

# %% [markdown]
# <h5><b>1.1 Create from CSV</b></h5>

# %%
df = pd.read_csv('output.csv')

df.head()
# Out:
#    Unnamed: 0 State  Account length  Area code International plan  \
# 0           0    KS             128        415                 No
# 1           1    OH             107        415                 No
# 2           2    NJ             137        415                 No
# 3           3    OH              84        408                Yes
# 4           4    OK              75        415                Yes
#
#   Voice mail plan  Number vmail messages  Total day minutes  Total day calls  \
# 0             Yes                     25              265.1            110.0
# 1             Yes                     26              161.6            123.0
# 2              No                      0              243.4            114.0
# 3              No                      0              299.4             71.0
# 4              No                      0              166.7            113.0
#
#    Total day charge  ...  Total night minutes  Total night calls  \
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0 State  Account length  Area code International plan  \
# 0           0    KS             128        415                 No
# 1           1    OH             107        415                 No
# 2           2    NJ             137        415                 No
# 3           3    OH              84        408                Yes
# 4           4    OK              75        415                Yes
# 5           5    AL             118        510                Yes
# 6           7    MO             147        415                Yes
# 7           8    LA             117        408                 No
# 8           9    WV             141        415                Yes
# 9          10    IN              65        415                 No
#
#   Voice mail plan  Number vmail messages  Total day minutes  Total day calls  \
# 0             Yes                     25              265.1            110.0
# 1             Yes                     26              161.6            123.0
# ...

# %% [markdown]
# <h5><b>1.2 Create from dictionary</b></h5>

# %%
data = {'name': ['chala', 'biniyam', 'baha'], 'age': [1,2,3]}

df_from_dict = pd.DataFrame.from_dict(data)

df_from_dict.drop(0, axis=0).iloc[0]
df_from_dict.to_json('mj.json')
df_from_dict.to_html('ohh.html')

# %%
def makesq(num):
    return num * num
# df_from_dict['age'].apply(lambda x : x * x)

df_from_dict['age'].apply(makesq)
# Out:
# 0    1
# 1    4
# 2    9
# Name: age, dtype: int64

# %% [markdown]
# <h5><b>2 Reading </b></h5>

# %%
df.head()
# Out:
#    Unnamed: 0 State  Account length  Area code International plan  \
# 0           0    KS             128        415                 No
# 1           1    OH             107        415                 No
# 2           2    NJ             137        415                 No
# 3           3    OH              84        408                Yes
# 4           4    OK              75        415                Yes
#
#   Voice mail plan  Number vmail messages  Total day minutes  Total day calls  \
# 0             Yes                     25              265.1            110.0
# 1             Yes                     26              161.6            123.0
# 2              No                      0              243.4            114.0
# 3              No                      0              299.4             71.0
# 4              No                      0              166.7            113.0
#
#    Total day charge  ...  Total night minutes  Total night calls  \
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0 State  Account length  Area code International plan  \
# 3302        3328    AZ             192        415                 No
# 3303        3329    WV              68        415                 No
# 3304        3330    RI              28        510                 No
# 3305        3331    CT             184        510                Yes
# 3306        3332    TN              74        415                 No
#
#      Voice mail plan  Number vmail messages  Total day minutes  \
# 3302             Yes                     36              156.2
# 3303              No                      0              231.1
# 3304              No                      0              180.8
# 3305              No                      0              213.8
# 3306             Yes                     25              234.4
#
#       Total day calls  Total day charge  ...  Total night minutes  \
# 3302             77.0             26.55  ...                279.1
# ...

# %%
df.tail(3)
# Out:
#       Unnamed: 0 State  Account length  Area code International plan  \
# 3304        3330    RI              28        510                 No
# 3305        3331    CT             184        510                Yes
# 3306        3332    TN              74        415                 No
#
#      Voice mail plan  Number vmail messages  Total day minutes  \
# 3304              No                      0              180.8
# 3305              No                      0              213.8
# 3306             Yes                     25              234.4
#
#       Total day calls  Total day charge  ...  Total night minutes  \
# 3304            109.0             30.74  ...                191.9
# 3305            105.0             36.35  ...                139.2
# 3306            113.0             39.85  ...                241.4
#
#       Total night calls  Total night charge  Total intl minutes  \
# 3304               91.0                8.64                14.1
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'State', 'Account length', 'Area code',
#        'International plan', 'Voice mail plan', 'Number vmail messages',
#        'Total day minutes', 'Total day calls', 'Total day charge',
#        'Total eve minutes', 'Total eve calls', 'Total eve charge',
#        'Total night minutes', 'Total night calls', 'Total night charge',
#        'Total intl minutes', 'Total intl calls', 'Total intl charge',
#        'Customer service calls', 'Churn', 'New Column', 'Churn Binary'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0                  int64
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls           float64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls           float64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls         float64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls    float64
# Churn                        bool
# New Column                  int64
# Churn Binary                int64
# dtype: object

# %%
df.describe(include='object')
# Out:
#        State International plan Voice mail plan
# count   3307               3307            3307
# unique    51                  2               2
# top       WV                 No              No
# freq     106               2985            2396

# %%
df.State
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3302    AZ
# 3303    WV
# 3304    RI
# 3305    CT
# 3306    TN
# Name: State, Length: 3307, dtype: object

# %%
df['International plan']
# Out:
# 0        No
# 1        No
# 2        No
# 3       Yes
# 4       Yes
#        ...
# 3302     No
# 3303     No
# 3304     No
# 3305    Yes
# 3306     No
# Name: International plan, Length: 3307, dtype: object

# %%
df[['International plan', 'State']]
# Out:
#      International plan State
# 0                    No    KS
# 1                    No    OH
# 2                    No    NJ
# 3                   Yes    OH
# 4                   Yes    OK
# ...                 ...   ...
# 3302                 No    AZ
# 3303                 No    WV
# 3304                 No    RI
# 3305                Yes    CT
# 3306                 No    TN
#
# [3307 rows x 2 columns]

# %%
df.State.unique()
# Out:
# array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MO', 'LA', 'WV', 'IN', 'RI', 'SC',
#        'VA', 'NE', 'WY', 'MT', 'IL', 'GA', 'MD', 'AR', 'ID', 'WI', 'OR',
#        'MI', 'DE', 'IA', 'UT', 'CO', 'CA', 'MN', 'SD', 'NC', 'WA', 'TX',
#        'NM', 'NV', 'HI', 'DC', 'NY', 'VT', 'KY', 'ME', 'AZ', 'AK', 'MS',
#        'MA', 'FL', 'NH', 'TN', 'PA', 'CT', 'ND'], dtype=object)

# %%
df.State.nunique()
# Out:
# 51

# %%
df[(df['International plan'] == 'No') & (df['Churn'] ==False) ]
# Out:
#       Unnamed: 0 State  Account length  Area code International plan  \
# 0              0    KS             128        415                 No
# 1              1    OH             107        415                 No
# 2              2    NJ             137        415                 No
# 7              8    LA             117        408                 No
# 10            11    RI              74        415                 No
# ...          ...   ...             ...        ...                ...
# 3301        3327    SC              79        415                 No
# 3302        3328    AZ             192        415                 No
# 3303        3329    WV              68        415                 No
# 3304        3330    RI              28        510                 No
# 3306        3332    TN              74        415                 No
#
#      Voice mail plan  Number vmail messages  Total day minutes  \
# 0                Yes                     25              265.1
# ...

# %%
df.iloc[14]
# Out:
# Unnamed: 0                   26
# State                        WY
# Account length               57
# Area code                   408
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        39
# Total day minutes         213.0
# Total day calls           115.0
# Total day charge          36.21
# Total eve minutes         191.1
# Total eve calls           112.0
# Total eve charge          16.24
# Total night minutes       182.7
# Total night calls         115.0
# Total night charge         8.22
# Total intl minutes          9.5
# Total intl calls              3
# Total intl charge          2.57
# Customer service calls      0.0
# Churn                     False
# New Column                  100
# Churn Binary                  0
# Name: 14, dtype: object

# %%
df.iloc[14, 0]
# Out:
# 26

# %%
df.iloc[14:32]
# Out:
#     Unnamed: 0 State  Account length  Area code International plan  \
# 14          26    WY              57        408                 No
# 15          27    MT              54        408                 No
# 16          28    MO              20        415                 No
# 17          30    IL             142        415                 No
# 18          39    NJ             149        408                 No
# 19          40    GA              98        408                 No
# 20          41    MD             135        408                Yes
# 21          42    AR              34        510                 No
# 22          43    ID             160        415                 No
# 23          44    WI              64        510                 No
# 24          45    OR              59        408                 No
# 25          46    MI              65        415                 No
# 26          47    DE             142        408                 No
# ...

# %%
dfc = df.set_index('State')

dfc
# Out:
#        Unnamed: 0  Account length  Area code International plan  \
# State
# KS              0             128        415                 No
# OH              1             107        415                 No
# NJ              2             137        415                 No
# OH              3              84        408                Yes
# OK              4              75        415                Yes
# ...           ...             ...        ...                ...
# AZ           3328             192        415                 No
# WV           3329              68        415                 No
# RI           3330              28        510                 No
# CT           3331             184        510                Yes
# TN           3332              74        415                 No
#
#       Voice mail plan  Number vmail messages  Total day minutes  \
# State
# KS                Yes                     25              265.1
# ...

# %%
dfc.loc['OH']
# Out:
#        Unnamed: 0  Account length  Area code International plan  \
# State
# OH              1             107        415                 No
# OH              3              84        408                Yes
# OH            152              65        408                 No
# OH            156              83        415                 No
# OH            231              63        415                Yes
# ...           ...             ...        ...                ...
# OH           3249             160        415                 No
# OH           3251              88        408                 No
# OH           3286             106        415                 No
# OH           3325              78        408                 No
# OH           3326              96        415                 No
#
#       Voice mail plan  Number vmail messages  Total day minutes  \
# State
# OH                Yes                     26              161.6
# ...

# %%
df.isnull().nunique()
# Out:
# Unnamed: 0                1
# State                     1
# Account length            1
# Area code                 1
# International plan        1
# Voice mail plan           1
# Number vmail messages     1
# Total day minutes         1
# Total day calls           1
# Total day charge          1
# Total eve minutes         1
# Total eve calls           1
# Total eve charge          1
# Total night minutes       1
# Total night calls         1
# Total night charge        1
# Total intl minutes        1
# Total intl calls          1
# Total intl charge         1
# Customer service calls    1
# Churn                     1
# New Column                1
# Churn Binary              1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.dropna()
# Out:
#       Unnamed: 0 State  Account length  Area code International plan  \
# 0              0    KS             128        415                 No
# 1              1    OH             107        415                 No
# 2              2    NJ             137        415                 No
# 3              3    OH              84        408                Yes
# 4              4    OK              75        415                Yes
# ...          ...   ...             ...        ...                ...
# 3302        3328    AZ             192        415                 No
# 3303        3329    WV              68        415                 No
# 3304        3330    RI              28        510                 No
# 3305        3331    CT             184        510                Yes
# 3306        3332    TN              74        415                 No
#
#      Voice mail plan  Number vmail messages  Total day minutes  \
# 0                Yes                     25              265.1
# ...

# %%
df.drop('Area code', axis=1)
# Out:
#       Unnamed: 0 State  Account length International plan Voice mail plan  \
# 0              0    KS             128                 No             Yes
# 1              1    OH             107                 No             Yes
# 2              2    NJ             137                 No              No
# 3              3    OH              84                Yes              No
# 4              4    OK              75                Yes              No
# ...          ...   ...             ...                ...             ...
# 3302        3328    AZ             192                 No             Yes
# 3303        3329    WV              68                 No              No
# 3304        3330    RI              28                 No              No
# 3305        3331    CT             184                Yes              No
# 3306        3332    TN              74                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.to_csv('akkam.csv')

# %%
df.to_json('jsn.json')

# %%
df.to_html('omg.html')
